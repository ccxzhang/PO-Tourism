# %%
import pandas as pd
import pdfplumber
import tabula

# %%
pdf_path = 'data/tonga/01-January-Migration-Report-2014.pdf'

# %% [markdown]
# ## `pdfplumber`

# %%
table_settings = {
    "vertical_strategy": "lines",
    "horizontal_strategy": "lines"
}

pdf = pdfplumber.open(pdf_path)

table = pdf.pages[3].extract_tables(table_settings)
pd.DataFrame(table[0])
# Out:
#                                                    0   \
# 0                                              Period
# 1                                                None
# 2   2005\n2006\n2007\n2008\n2009\n2010\n2011\n2012...
# 3                                                2010
# 4   January\nFebruary\nMarch\nApril\nMay\nJune\nJu...
# 5                                                2011
# 6   January\nFebruary\nMarch\nApril\nMay\nJune\nJu...
# 7                                                2012
# 8   January\nFebruary\nMarch\nApril\nMay\nJune\nJu...
# 9                                                2013
# 10  January\nFebruary\nMarch\nApril\nMay\nJune\nJu...
# 11                                               2014
# 12                                            January
#
#                                                    1     2      3      4   \
# 0                                   Visitors Arrivals  None   None   None
# ...

# %%
pdf.pages[3].to_image()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniforge3/lib/python3.9/site-packages/wand/api.py:154, in <module>
#     153 try:
# --> 154     libraries = load_library()
#     155 except (OSError, IOError):
#
# File ~/miniforge3/lib/python3.9/site-packages/wand/api.py:143, in load_library()
#     142     return libwand, libmagick
# --> 143 raise IOError('cannot find library; tried paths: ' + repr(tried_paths))
#
# OSError: cannot find library; tried paths: []
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 pdf.pages[3].to_image()
#
# File ~/miniforge3/lib/python3.9/site-packages/pdfplumber/page.py:376, in Page.to_image(self, **conversion_kwargs)
#     371 def to_image(self, **conversion_kwargs: Any) -> "PageImage":
# ...

# %% [markdown]
# ## `tablua-py`

# %%
dfs = tabula.read_pdf(pdf_path, pages="4-6", stream=True)
df = dfs[0]
df.columns = df.iloc[0, :].to_list()
df
# Out:
# Got stderr: Oct 31, 2022 12:47:15 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: inherited resources of source document are not imported to destination page
# Oct 31, 2022 12:47:15 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: call importedPage.setResources(page.getResources()) to do this
# Oct 31, 2022 12:47:16 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: inherited resources of source document are not imported to destination page
# Oct 31, 2022 12:47:16 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: call importedPage.setResources(page.getResources()) to do this
# Oct 31, 2022 12:47:17 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: inherited resources of source document are not imported to destination page
# Oct 31, 2022 12:47:17 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: call importedPage.setResources(page.getResources()) to do this

# %%
df.iloc[1:].head(20)
# Out:
#        Period       Air Ship  Yacht   Total Air Ship Yacht   Total     Air  \
# 1        2005  42,437 11,840    943  55,220         21,066  21,066  63,503
# 2        2006  46,268 10,809    868  57,945         20,707  20,707  66,975
# 3        2007   43,344 8,790  1,140  53,274         22,313  22,313  65,657
# 4        2008  50,462 14,599  1,828  66,889         24,239  24,239  74,701
# 5        2009  45,711 27,641  1,317  74,669         25,134  25,134  70,845
# 6        2010  47,081 16,265  1,659  65,005         24,501  24,501  71,582
# 7        2011  46,005 20,519  1,849  68,373         26,587  26,587  72,592
# 8        2012   47,457 7,957  1,816  57,230         25,170  25,107  72,627
# 9        2013   48,188 9,432  2,045  59,665         25,808  25,808  73,996
# 10        NaN            NaN    NaN     NaN            NaN    2010     NaN
# 11    January      3,158 646      4   3,808          3,019   3,019   6,177
# ...

# %% [markdown]
# ## `pdfminer`

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

# %%
output_string = StringIO()
with open(pdf_path, 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

# %%
output_string.getvalue()
# Out:
# "INTERNATIONAL ARRIVALS AND DEPARTURES\nINTERNATIONAL ARRIVALS AND DEPARTURES\nINTERNATIONAL ARRIVALS AND DEPARTURES\nJanuary 2014\nJanuary 2014\nJanuary 2014\n\nGovernment of Tonga\nGovernment of Tonga\nGovernment of Tonga\n\nSD18M-07\nSD18M-07\nSD18M-07\n\nStatistical Bulletin\nStatistical Bulletin\nStatistical Bulletin\n\nMonth of\nMonth of\n\nChange from\nChange from\n\nChange from\nChange from\n\n January 2014\n January 2014\n\nNumber\nNumber\n\nprevious month\nprevious month\n\nprevious year\nprevious year\n\nAll Arrivals\nAll Arrivals\nAir Visitors\nAir Visitors\nAir Returning Residents\nAir Returning Residents\nCruise Ships\nCruise Ships\nYachts\nYachts\nAll Departures\nAll Departures\n\n7,875\n7,875\n3,259\n3,259\n3,167\n3,167\n1,446\n1,446\n3\n3\n9,472\n9,472\n\n-7.2\n-7.2\n-49.3\n-49.3\n54.6\n54.6\n0.0\n0.0\n-76.9\n-76.9\n30.7\n30.7\n\n13.4\n13.4\n11.3\n11.3\n2.7\n2.7\n56.8\n56.8\n-66.7\n-66.7\n13.2\n13.2\n\nFig. 1:  January Air Arrivals and Departures 2003 - 2013\nFig. 1:
# ...
